# %%
#najprv si naimportujem knižnice, ktoré budem používať
import tensorflow
import pandas as pd
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras.layers import Dropout
from keras import regularizers
# %matplotlib inline

# %%
def resizeplot(l,a):
    plt.figure(figsize=(l,a))  #funkcia pomocou ktorej zmením velkost grafov

# %% [markdown]
# # Dataset Zillow’s Home Value Prediction
# dataset je prevzatý od spoločnosti Zillow’s Home Value Prediction Kaggle, ako úlohu na predpovedanie som si zvolila určiť, či je cena domu nad alebo pod strednou hodnotou.
# # Údaje o datasete:
# - Plocha pozemku (v štvorcových stôp)
# - Celková kvalita (stupnica od 1 do 10)
# - Celkový stav (stupnica od 1 do 10)
# - Celková suterénna plocha (v štvorcových stôp)
# - Počet plných kúpeľní
# - Počet polovičných kúpeľní
# - Počet spální na poschodí
# - Celkový počet izieb na poschodí
# - Počet krbov
# - Garážová plocha (v štvorcových stopách)
# - údaj či je cena nad alebo pod priemerom

# %%
#pomocou knižnice pandas si načítame csv súbor
df = pd.read_csv('housepricedata.csv')

# %%
df #zobrazíme si csv súbor
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0                3             8           0         548                 1
# 1                3             6           1         460                 1
# 2                3             6           1         608                 1
# 3                3             7           1         642                 0
# 4                4             9           1         836                 1
# ...            ...           ...         ...         ...               ...
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0
#
# [1460 rows x 11 columns]

# %%
df.info() #zobrazím si informacie o datasete
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   OverallQual       1460 non-null   int64
#  2   OverallCond       1460 non-null   int64
#  3   TotalBsmtSF       1460 non-null   int64
#  4   FullBath          1460 non-null   int64
#  5   HalfBath          1460 non-null   int64
#  6   BedroomAbvGr      1460 non-null   int64
#  7   TotRmsAbvGrd      1460 non-null   int64
#  8   Fireplaces        1460 non-null   int64
#  9   GarageArea        1460 non-null   int64
#  10  AboveMedianPrice  1460 non-null   int64
# dtypes: int64(11)
# memory usage: 125.6 KB

# %%
resizeplot(10,5)
sns.countplot(x='TotRmsAbvGrd',data=df)  #príklad ako by sme si vykreslili  informácie o datach pomocou grafu(konkrétne počet izieb)
# Out:
# <AxesSubplot:xlabel='TotRmsAbvGrd', ylabel='count'>

# %%
#Množina údajov, ktorú teraz máme, sa nachádza v dátovom rámci pandas, prevedieme ho na pole aby sme jednoducho získali hodnoty
dataset = df.values
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]], dtype=int64)

# %%
#dataset sme  rozdelili na vstupné funkcie (X) a funkciu, ktorú chceme predpovedať (Y)
X = dataset[:,0:10]
Y = dataset[:,10]

# %%
#normalizácia dát je veľmi dôležitá, použijem min-max scaler od scikit-learn, ktorý upraví dáta tak, aby boli v rozmedzí 0 a 1.
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale #zobrazím si x_scale
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %%
#teraz si potrebujem rozdeliť dáta na trénovacie a testovacie, na to použijeme funckiu train_test_split z knižnice scikit-learn
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %%
#rozdelí veľkosť val_and_test rovnako na overovaciu sadu a testovaciu sadu
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
#teraz máme celkovo šesť premenných pre naše množiny údajov, ktoré budeme používať
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %% [markdown]
# Trénovacia sada má 1022 dátových bodov, zatiaľ čo validačná a testovacia sada má po 219 dátových bodoch. Premenné X majú 10 vstupných funkcií, zatiaľ čo premenné Y majú iba jednu vlastnosť na predpovedanie.

# %% [markdown]
# ![ns.png](attachment:ns.png)

# %%
#definujem si architektúru siete
model = Sequential([   #model - sekvenčný
    Dense(32, activation='relu', input_shape=(10,)),   #hustota 32, vstupná vrstva 10
    Dense(32, activation='relu'),   #nemusíme popisovať vstupný tvar, pretože Keras ho môže odvodiť z výstupu našej prvej vrstvy
    Dense(1, activation='sigmoid'),  #tretia vrstva je hustá vrstva s 1 neurónom a aktiváciou sigmoidu
])

# %% [markdown]
# Link: https://keras.io/guides/sequential_model/

# %%
model.compile(optimizer='sgd',  #Sgd označuje stochastický gradientový zostup
              loss='binary_crossentropy', #chybová funkcia pre výstupy, hodnoty 1 alebo 0
              metrics=['accuracy'])  #presnosť

# %%
hist = model.fit(X_train, Y_train,  #určujem na ktorých údajoch trénujeme, teda X_train a Y_train
          batch_size=32, epochs=100,  #data si nasekam na tzv. "batches a určím počet iterácií
          validation_data=(X_val, Y_val)) #zadám validačné údaje
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 17ms/step - loss: 0.7039 - accuracy: 0.4932 - val_loss: 0.6958 - val_accuracy: 0.4977
# Epoch 2/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6891 - accuracy: 0.5440 - val_loss: 0.6859 - val_accuracy: 0.5982
# Epoch 3/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6788 - accuracy: 0.6937 - val_loss: 0.6784 - val_accuracy: 0.6941
# Epoch 4/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6710 - accuracy: 0.7505 - val_loss: 0.6724 - val_accuracy: 0.7489
# Epoch 5/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6642 - accuracy: 0.7877 - val_loss: 0.6671 - val_accuracy: 0.7580
# Epoch 6/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6584 - accuracy: 0.7759 - val_loss: 0.6622 - val_accuracy: 0.7626
# Epoch 7/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6528 - accuracy: 0.7877 - val_loss: 0.6573 - val_accuracy: 0.7626
# Epoch 8/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6471 - accuracy: 0.7828 - val_loss: 0.6525 - val_accuracy: 0.7580
# Epoch 9/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6416 - accuracy: 0.7750 - val_loss: 0.6475 - val_accuracy: 0.7808
# Epoch 10/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6359 - accuracy: 0.7769 - val_loss: 0.6424 - val_accuracy: 0.7808
# Epoch 11/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6300 - accuracy: 0.7886 - val_loss: 0.6371 - val_accuracy: 0.7900
# Epoch 12/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6239 - accuracy: 0.7984 - val_loss: 0.6318 - val_accuracy: 0.7945
# Epoch 13/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6176 - accuracy: 0.7994 - val_loss: 0.6261 - val_accuracy: 0.7945
# Epoch 14/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6110 - accuracy: 0.7984 - val_loss: 0.6201 - val_accuracy: 0.7945
# Epoch 15/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6041 - accuracy: 0.8141 - val_loss: 0.6137 - val_accuracy: 0.7991
# Epoch 16/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5967 - accuracy: 0.8170 - val_loss: 0.6069 - val_accuracy: 0.8037
# Epoch 17/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5887 - accuracy: 0.8239 - val_loss: 0.5997 - val_accuracy: 0.8037
# Epoch 18/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5803 - accuracy: 0.8258 - val_loss: 0.5918 - val_accuracy: 0.8082
# Epoch 19/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5714 - accuracy: 0.8483 - val_loss: 0.5839 - val_accuracy: 0.8128
# Epoch 20/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5619 - accuracy: 0.8346 - val_loss: 0.5752 - val_accuracy: 0.8174
# Epoch 21/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5524 - accuracy: 0.8513 - val_loss: 0.5665 - val_accuracy: 0.8265
# Epoch 22/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5425 - accuracy: 0.8562 - val_loss: 0.5578 - val_accuracy: 0.8311
# Epoch 23/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5327 - accuracy: 0.8620 - val_loss: 0.5491 - val_accuracy: 0.8356
# Epoch 24/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5228 - accuracy: 0.8571 - val_loss: 0.5401 - val_accuracy: 0.8356
# Epoch 25/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5129 - accuracy: 0.8562 - val_loss: 0.5309 - val_accuracy: 0.8356
# Epoch 26/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5027 - accuracy: 0.8650 - val_loss: 0.5219 - val_accuracy: 0.8356
# Epoch 27/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.
# Epoch 65/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3050 - accuracy: 0.8826 - val_loss: 0.3416 - val_accuracy: 0.8356
# Epoch 66/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3039 - accuracy: 0.8796 - val_loss: 0.3404 - val_accuracy: 0.8311
# Epoch 67/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3021 - accuracy: 0.8806 - val_loss: 0.3393 - val_accuracy: 0.8311
# Epoch 68/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3012 - accuracy: 0.8767 - val_loss: 0.3376 - val_accuracy: 0.8356
# Epoch 69/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2997 - accuracy: 0.8826 - val_loss: 0.3363 - val_accuracy: 0.8356
# Epoch 70/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2994 - accuracy: 0.8777 - val_loss: 0.3352 - val_accuracy: 0.8447
# Epoch 71/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2971 - accuracy: 0.8826 - val_loss: 0.3351 - val_accuracy: 0.8402
# Epoch 72/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2969 - accuracy: 0.8806 - val_loss: 0.3333 - val_accuracy: 0.8356
# Epoch 73/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2945 - accuracy: 0.8777 - val_loss: 0.3326 - val_accuracy: 0.8584
# Epoch 74/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2945 - accuracy: 0.8826 - val_loss: 0.3311 - val_accuracy: 0.8493
# Epoch 75/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2935 - accuracy: 0.8875 - val_loss: 0.3302 - val_accuracy: 0.8356
# Epoch 76/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2933 - accuracy: 0.8787 - val_loss: 0.3285 - val_accuracy: 0.8402
# Epoch 77/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2924 - accuracy: 0.8836 - val_loss: 0.3283 - val_accuracy: 0.8402
# Epoch 78/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2921 - accuracy: 0.8796 - val_loss: 0.3266 - val_accuracy: 0.8402
# Epoch 79/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2906 - accuracy: 0.8845 - val_loss: 0.3256 - val_accuracy: 0.8493
# Epoch 80/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2895 - accuracy: 0.8816 - val_loss: 0.3247 - val_accuracy: 0.8539
# Epoch 81/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2894 - accuracy: 0.8855 - val_loss: 0.3238 - val_accuracy: 0.8447
# Epoch 82/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2881 - accuracy: 0.8836 - val_loss: 0.3228 - val_accuracy: 0.8539
# Epoch 83/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2874 - accuracy: 0.8845 - val_loss: 0.3220 - val_accuracy: 0.8493
# Epoch 84/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2873 - accuracy: 0.8894 - val_loss: 0.3210 - val_accuracy: 0.8539
# Epoch 85/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2868 - accuracy: 0.8845 - val_loss: 0.3205 - val_accuracy: 0.8493
# Epoch 86/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2857 - accuracy: 0.8855 - val_loss: 0.3201 - val_accuracy: 0.8447
# Epoch 87/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2856 - accuracy: 0.8826 - val_loss: 0.3186 - val_accuracy: 0.8584
# Epoch 88/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2838 - accuracy: 0.8845 - val_loss: 0.3191 - val_accuracy: 0.8676
# Epoch 89/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2836 - accuracy: 0.8845 - val_loss: 0.3174 - val_accuracy: 0.8539
# Epoch 90/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2829 - accuracy: 0.8875 - val_loss: 0.3162 - val_accuracy: 0.8584
# Epoch 91/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2825 - accuracy: 0.8855 - val_loss: 0.3156 - val_accuracy: 0.8493
# Epoch 92/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2823 - accuracy: 0.8865 - val_loss: 0.3145 - val_accuracy: 0.8539
# Epoch 93/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2815 - accuracy: 0.8836 - val_loss: 0.3138 - val_accuracy: 0.8539
# Epoch 94/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2812 - accuracy: 0.8885 - val_loss: 0.3131 - val_accuracy: 0.8539
# Epoch 95/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2802 - accuracy: 0.8826 - val_loss: 0.3123 - val_accuracy: 0.8584
# Epoch 96/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2790 - accuracy: 0.8855 - val_loss: 0.3126 - val_accuracy: 0.8584
# Epoch 97/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2791 - accuracy: 0.8875 - val_loss: 0.3118 - val_accuracy: 0.8584
# Epoch 98/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2786 - accuracy: 0.8914 - val_loss: 0.3118 - val_accuracy: 0.8584
# Epoch 99/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2780 - accuracy: 0.8885 - val_loss: 0.3095 - val_accuracy: 0.8584
# Epoch 100/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2777 - accuracy: 0.8865 - val_loss: 0.3093 - val_accuracy: 0.8630

# %%
model.evaluate(X_test, Y_test)[1] #vygenerujem si presnosť
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2785 - accuracy: 0.8995
# 0.8995434045791626

# %%
resizeplot(10,6) 
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('graf chybovosti')
plt.ylabel('chyby')
plt.xlabel('Počet iterácií')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
resizeplot(10,6)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model presnosti')
plt.ylabel('Presnosť')
plt.xlabel('Počet iterácií')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()
